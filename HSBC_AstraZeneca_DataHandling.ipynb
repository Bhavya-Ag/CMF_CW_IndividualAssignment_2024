# %%
# Install yfinance if not already installed
# !pip install yfinance

# Import necessary libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Define the ticker symbols for HSBC and AstraZeneca
tickers = ['HSBA.L', 'AZN.L']

# Calculate the start date (two years ago from today) and today's date
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=2*365)).strftime('%Y-%m-%d')

# Download historical data for the past two years until today
data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']

# Plot HSBC stock price movement
plt.figure(figsize=(10,6))
plt.plot(data.index, data['HSBA.L'], label='HSBC', color='blue')
plt.title('HSBC Stock Price (Past 2 Years)')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.grid(True)
plt.legend()
plt.show()

# Plot AstraZeneca stock price movement
plt.figure(figsize=(10,6))
plt.plot(data.index, data['AZN.L'], label='AstraZeneca', color='green')
plt.title('AstraZeneca Stock Price (Past 2 Years)')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.grid(True)
plt.legend()
plt.show()

# Calculate daily returns for each stock
daily_returns = data.pct_change()

# Calculate annualised average returns for each stock over 2 years
annualised_returns = ((data.iloc[-1] / data.iloc[0]) ** (1/2)) - 1

# Calculate annualised standard deviations (volatility)
annualised_std_dev = daily_returns.std() * np.sqrt(252)

# Display results
print(f"Annualised Average Returns:\n{annualised_returns}\n")
print(f"Annualised Standard Deviations (Volatility):\n{annualised_std_dev}\n")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# [*********************100%***********************]  2 of 2 completed
# Annualised Average Returns:
# Ticker
# AZN.L    -0.012635
# HSBA.L    0.325100
# dtype: float64
#
# Annualised Standard Deviations (Volatility):
# Ticker
# AZN.L     0.216559
# HSBA.L    0.212347
# dtype: float64
